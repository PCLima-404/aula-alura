# %% [markdown]
# <a href="https://colab.research.google.com/github/PCLima-404/aula-alura/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q google-generativeai

# %%
import numpy as np
import pandas as pd
import google.generativeai as genai

GOOGLE_API_KEY = "AIzaSyCjKS_RA6RMKY5kiMD8OGPZiqQFM2enDfg"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
    if 'embedContent' in m.supported_generation_methods:
      print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
#exemplo_de_titulo
title = "A próxima geração de IA para desenvolvedores e Google Workspace"
sample_text = (f"Título: A próxima geração de IA para desenvolvedores e Google Workspace"
"\n"
"Artigo completo:\n"
"I"
"\n"
"Gemini API & Google AI Studio: Uma maneira acessível de explorar e criar protótipos com aplicações de IA generativa")

embeddings = genai.embed_content(model="models/embedding-001",
                                 content=sample_text,

                                 task_type="RETRIEVAL_DOCUMENT")

print(embeddings)
# Out:
# {'embedding': [0.042251557, -0.033521634, -0.03881127, 0.018050734, 0.08316532, 0.020756193, -0.01099382, -0.033450603, 0.03548488, 0.065345846, 0.014149243, 0.0058728317, -0.053711217, -0.01333674, 0.0007076687, -0.020538567, 0.030676303, -0.0020199576, -0.027691495, -0.0039271973, 0.013966088, 0.012757952, -0.017384185, -0.049692836, -0.021187838, 0.010005013, 0.0066069257, -0.040629454, -0.03601874, 0.015461078, -0.04321001, 0.043430455, -0.0326133, 0.016980981, -0.023251213, -0.03650572, -0.029489325, -0.032148518, 0.0046760477, -0.004494519, 0.00866504, -0.09168183, -0.01582694, 0.02802059, -0.01299581, -0.023172433, 0.013349052, 0.053840354, 0.015330445, -0.05169293, 0.02518843, 0.026749091, 0.085435055, -0.03289598, -0.0016076388, -0.025267882, 0.027808318, -0.015938463, 0.016752632, 0.013957837, 2.7483431e-05, 0.03678992, 0.0046283985, 0.033698656, 0.0035371152, -0.07790787, -0.05055585, -0.004208495, 0.017660515, 0.037936322, 0.0061589894, -0.00772546, 0.060753122, -0.055334
# ...

# %%
# Listagem de documentos que serão buscados
DOCUMENT1 = {
    "Título": "Operação do sistema de controle climático",
    "Conteúdo": "O Googlecar tem um sistema de controle climático que permite ajustar a temperatura e o fluxo de ar no carro. Para operar o sistema, basta usar os comandos de voz ou a tela sensível ao toque."
}

DOCUMENT2 = {
    "Título": "Touchscreen",
    "Conteúdo": "O seu Googlecar tem uma grande tela sensível ao toque que fornece acesso a uma variedade de recursos, incluindo navegação, entretenimento e configurações do veículo."
}

DOCUMENT3 = {
    "Título": "Mudança de marchas",
    "Conteúdo": "Seu Googlecar tem uma transmissão automática. Para trocar as marchas, basta mover a alavanca de câmbio para a posição desejada."
}

documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3]

# %%
df = pd.DataFrame(documents)
df.columns = ["Título", "Conteúdo"]
df
# Out:
#                                       Título  \
# 0  Operação do sistema de controle climático
# 1                                Touchscreen
# 2                         Mudança de marchas
#
#                                             Conteúdo
# 0  O Googlecar tem um sistema de controle climáti...
# 1  O seu Googlecar tem uma grande tela sensível a...
# 2  Seu Googlecar tem uma transmissão automática. ...

# %%
model= "models/embedding-001"

# %%
def embed_fn(title, text):
  return genai.embed_content(model=model,
                            content=text,
                            title=title,
                            task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
df['Embeddings'] = df.apply(lambda row: embed_fn(row['Título'], row['Conteúdo']), axis=1)

df
# Out:
#                                       Título  \
# 0  Operação do sistema de controle climático
# 1                                Touchscreen
# 2                         Mudança de marchas
#
#                                             Conteúdo  \
# 0  O Googlecar tem um sistema de controle climáti...
# 1  O seu Googlecar tem uma grande tela sensível a...
# 2  Seu Googlecar tem uma transmissão automática. ...
#
#                                           Embeddings
# 0  [-0.00861495, -0.028297551, -0.051801536, 0.04...
# 1  [0.019381056, -0.039335743, -0.013499535, -0.0...
# 2  [0.00018316552, -0.03903683, 0.0017067897, 0.0...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
    embedding_da_consulta = genai.embed_content(model=model,
                                                 content=consulta,
                                                 task_type="RETRIEVAL_QUERY")["embedding"]

    produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)

    indice = np.argmax(produtos_escalares)
    return df.iloc[indice]["Conteúdo"]

# %%
consulta ="como se troca de marcha no carro do google?"

trecho = gerar_e_buscar_consulta (consulta, df, model)
print (trecho)
# Out:
# Seu Googlecar tem uma transmissão automática. Para trocar as marchas, basta mover a alavanca de câmbio para a posição desejada.

# %%
generation_config = {
    "temperature": 0.5,
    "candidate_count": 1,
}

# %%
prompt = f"Reescreva esse texto de uma forma mais descontraída, sem adicionar informações que não façam parte do texto: {consulta}"

model1_2 = genai.GenerativeModel("gemini-1.0-pro",
                                 generation_config=generation_config)

response = model1_2.generate_content(prompt)
print(response.text)
# Out:
# **Como dar uma voltinha no carro do Google**
#
# Tá afim de dar um rolê no carango do Google? Então liga o motor e deixa eu te guiar nessa aventura!
#
# **1. Pé no freio**
#
# Antes de mais nada, pisa no freio pra garantir que o carro não vá sair voando.
#
# **2. Seletor de marcha**
#
# Olha pro console central e acha o seletor de marcha. Ele parece uma alavanca ou um botão.
#
# **3. Escolhe a marcha**
#
# Pra ir pra frente, empurra a alavanca pra cima ou aperta o botão "D". Se quiser dar ré, puxa a alavanca pra baixo ou aperta o botão "R".
#
# **4. Tira o pé do freio**
#
# Com a marcha engatada, tira o pé do freio e o carro vai começar a se mover.
#
# **5. Acelera**
#
# Pra acelerar, aperta o pedal da direita. Quanto mais fundo você pisar, mais rápido o carro vai.
#
# **6. Freia**
#
# Pra frear, aperta o pedal da esquerda. Quanto mais fundo você pisar, mais rápido o carro vai parar.
#
# **7. Troca de marcha**
#
# ...
